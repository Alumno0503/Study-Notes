# %% [markdown]
# # 李宏毅 Diffusion Model
# 以下为李宏毅老师讲解的text to image课程截图，其中也包括diffusion model的部分，由Yiting Yan整理，仅作个人学习使用

# %% [markdown]
# DDPM
#
# <div style="display: flex; gap: 10px; width: 100%;">
#     <img src="DDPM1.png" style="width: 48%; max-width: 100%; height: auto;" alt="扩散模型原理">
#     <img src="DDPM2.png" style="width: 48%; max-width: 100%; height: auto;" alt="去噪模组内部">
# </div>

# %% [markdown]
# Framework & Stable diffusion
# <div style="display: flex; gap: 10px; width: 100%;">
#     <img src="framework2.png" style="width: 48%; max-width: 100%; height: auto;" alt="描述1">
#     <img src="sd.png" style="width: 48%; max-width: 100%; height: auto;" alt="描述2">
# </div>
